# %%
# %pip install investpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# You are using pip version 19.0.3, however version 22.0.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import investpy

df = investpy.get_stock_historical_data(stock='AAL',
                                        country='United States',
                                        from_date='01/01/2022',
                                        to_date='01/03/2022')
print(df.head())
# Out:
#              Open   High    Low  Close    Volume Currency
# Date
# 2022-01-03  18.23  19.18  18.20  18.75  42696548      USD
# 2022-01-04  19.22  19.46  18.85  19.02  29079442      USD
# 2022-01-05  19.13  19.39  18.51  18.68  34220768      USD
# 2022-01-06  18.89  19.06  18.35  18.57  18896644      USD
# 2022-01-07  18.75  19.59  18.58  19.28  42399468      USD

# %%
search_result = investpy.search_quotes(text='apple', products=['stocks'],
                                       countries=['united states'], n_results=1)
print(search_result)
# Out:
# {"id_": 6408, "name": "Apple Inc", "symbol": "AAPL", "country": "united states", "tag": "/equities/apple-computer-inc", "pair_type": "stocks", "exchange": "NASDAQ"}

# %%
data = investpy.get_crypto_historical_data(crypto='waves',
                                           from_date='01/01/2020',
                                           to_date='01/03/2022')

data
# Out:
#                Open     High      Low    Close    Volume Currency
# Date
# 2020-01-01   1.0162   1.1045   1.0112   1.0553   5490950      USD
# 2020-01-02   1.0553   1.0600   0.9496   0.9497   4740452      USD
# 2020-01-03   0.9497   1.0241   0.9244   0.9637   7573672      USD
# 2020-01-04   0.9637   0.9943   0.9400   0.9514   4558315      USD
# 2020-01-05   0.9514   0.9517   0.8834   0.8896   3065119      USD
# ...             ...      ...      ...      ...       ...      ...
# 2022-02-25   9.5292  10.6674   9.2592  10.5409   1910120      USD
# 2022-02-26  10.5409  12.7659  10.4293  12.2600   4600816      USD
# 2022-02-27  12.2600  13.0084  11.0409  11.2100   4182103      USD
# 2022-02-28  11.2100  16.4099  11.1028  16.1502   6208069      USD
# 2022-03-01  16.1502  19.7236  16.1502  17.4432  11064674      USD
#
# [791 rows x 6 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd

# %%
rolling = data.rolling(365, center=True)

data_2 = pd.DataFrame({'input': data,
                     'one-year rolling_mean': rolling.mean(),
                     'one-year rolling_std': rolling.std()})

ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8636\1811950073.py in <module>
#       3 data_2 = pd.DataFrame({'input': data,
#       4                      'one-year rolling_mean': rolling.mean(),
# ----> 5                      'one-year rolling_std': rolling.std()})
#       6
#       7 ax = data.plot(style=['-', '--', ':'])
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
import matplotlib.pyplot as plt

data.plot(alpha=0.5, style='-')
data.resample('BA').mean().plot(style=':')
data.asfreq('BA').plot(style='--');

plt.legend(['precio', 'volumen', 'cierre'],
           loc='upper left');

# %%
data['Volume'].max()
# Out:
# 20255896

# %%
data['Volume'].min()
# Out:
# 264

# %%
data['Close'].max()
# Out:
# 67527.9

# %%
from sklearn.datasets import load_iris, load_boston
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
conteo = data['High'].value_counts(ascending=True)

plt.figure(figsize=(5,20))
plt.hlines(y=conteo.index,
           xmin=140,
           xmax=conteo,
           color='skyblue')
plt.plot(conteo, conteo.index, "o");
